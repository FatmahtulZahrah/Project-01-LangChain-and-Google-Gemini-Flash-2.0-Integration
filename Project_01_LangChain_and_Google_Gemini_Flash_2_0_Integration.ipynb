# %% [markdown]
# ### **Project 01: LangChain and Google Gemini Flash 2.0 Integration**

# %% [markdown]
# ### **LangChain with Google Gemini Flash**
# This notebook demonstrates how to use LangChain with Google Gemini Flash to create a conversational AI that answers user questions.
#
# **Installation**\
# Install the required libraries:
#
# ```
# !pip install langchain
# ```
# **Code Explanation**
# 1. Import Libraries
# ```
# from langchain.prompts import PromptTemplate
# from langchain.chains import LLMChain
# from google.colab import userdata
# from langchain_google_genai import ChatGoogleGenerativeAI
# ```
# 2. **Setup API Key**\
# The API key is securely fetched from userdata:
#
#  `gemini_api_key = userdata.get('GEMINI_API_KEY')`
# 3. **Configure the LLM**\
# Set up the Google Gemini Flash model with desired parameters:
# ```
# llm = ChatGoogleGenerativeAI(
#     model="gemini-1.5-flash",
#     max_retries=2,
#     temperature=0.2,
#     api_key=gemini_api_key
# )
# ```
#
#
# 4. **Create a Prompt Template**\
# Define a prompt template to customize how the model responds:
# ```
# prompt_template = PromptTemplate(
#     input_variables=["question"],
#     template="You are a helpful assistant. Answer the following question:\n\n{question}"
# )
# ```
# 5. **Initialize the Chain**\
# Combine the LLM and the prompt template into an executable chain:
#
#  `chain = LLMChain(llm=llm, prompt=prompt_template)`
# 6. **Run the Chain**
# Pass a question to the chain and print the response:
#
# ```
# question = "What is LangChain?"
# response = chain.run({"question": question})
# ```

# %%
# !pip install langchain
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.3.12)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.11.10)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.25 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.25)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.3)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.2.3)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.10.3)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.25->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.25->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.25->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.17->langchain) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.25->langchain) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.2.2)

# %%
# !pip install langchain-google-genai
# Out:
# Requirement already satisfied: langchain-google-genai in /usr/local/lib/python3.10/dist-packages (2.0.7)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-generativeai<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from langchain-google-genai) (0.8.3)
# Requirement already satisfied: langchain-core<0.4,>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from langchain-google-genai) (0.3.25)
# Requirement already satisfied: pydantic<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain-google-genai) (2.10.3)
# Requirement already satisfied: google-ai-generativelanguage==0.6.10 in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.6.10)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.19.2)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.155.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.27.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.25.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-ai-generativelanguage==0.6.10->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.25.0)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3.15->langchain-google-genai) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3.15->langchain-google-genai) (1.33)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3.15->langchain-google-genai) (0.2.3)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3.15->langchain-google-genai) (24.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3.15->langchain-google-genai) (9.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=2->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=2->langchain-google-genai) (2.27.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.66.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.9)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3.15->langchain-google-genai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (1.0.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.1.1)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.68.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.62.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (3.2.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (0.14.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.2.3)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (1.2.2)

# %%
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain

# %%
from google.colab import userdata
from langchain_google_genai import ChatGoogleGenerativeAI


gemini_api_key = userdata.get('GEMINI_KEY')
llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash-exp",
    max_retries=2,
    temperature=0.2,
    api_key=gemini_api_key
)

# %%
prompt_template = PromptTemplate(
    input_variables=["question"],
    template="Can you assist on following questions. Answer the following question:\n\n{question}"
)

# %%
chain = LLMChain(llm=llm, prompt=prompt_template)

# %%
question = "What is LangChain framework?"
response = chain.run({"question": question})

print("Answer:", response)
# Out:
# Answer: Okay, let's break down what the LangChain framework is.
#
# **LangChain is a framework designed to make it easier to build applications that leverage the power of large language models (LLMs).**
#
# Think of it as a toolkit that provides a structured way to:
#
# * **Connect to LLMs:** LangChain provides a standardized interface to interact with various LLMs, whether they are hosted by OpenAI, Google, or other providers, or even open-source models. This means you don't have to write custom code for each model you want to use.
# * **Chain LLM Calls:** The core idea behind LangChain is the concept of "chains." These chains allow you to sequence multiple LLM calls together, passing the output of one call as the input to the next. This enables you to build more complex and sophisticated applications than just a single prompt-response interaction.
# * **Integrate with External Data:** LangChain allows you to connect your LLMs to external data sources like databases, APIs, and documents. This is crucial for building applications that can reason over real-world information and provide more context-aware responses.
# * **Manage Memory:** Many applications require the LLM to remember previous interactions. LangChain provides mechanisms for managing conversation history and other forms of memory, allowing for more coherent and context-aware conversations.
# * **Use Tools:** LangChain allows you to equip your LLM with tools, such as search engines, calculators, or other APIs. This enables the LLM to perform actions beyond just generating text, making it a more powerful agent.
# * **Build Agents:** LangChain provides the building blocks for creating AI agents that can reason, plan, and execute tasks autonomously. These agents can use tools and interact with the environment to achieve specific goals.
#
# **Key Concepts in LangChain:**
#
# * **Models:** The LLMs themselves (e.g., GPT-3, LLaMA).
# * **Prompts:** The input text you provide to the LLM.
# * **Chains:** Sequences of LLM calls and other operations.
# * **Indexes:** Structures for storing and retrieving data (e.g., vector databases).
# * **Memory:** Mechanisms for storing and retrieving conversation history.
# * **Agents:** Autonomous entities that can use tools and interact with the environment.
# * **Tools:** External resources that the LLM can use.
#
# **Why Use LangChain?**
#
# * **Abstraction:** It simplifies the process of working with LLMs by providing a high-level API.
# * **Flexibility:** It supports a wide range of LLMs, data sources, and tools.
# * **Composability:** It allows you to combine different components to build complex applications.
# * **Rapid Development:** It speeds up the development process by providing pre-built components and patterns.
# * **Community Support:** It has a large and active community, providing resources and support.
#
# **In Summary:**
#
# LangChain is a powerful framework that makes it easier to build sophisticated applications powered by large language models. It provides a structured way to connect to LLMs, chain calls together, integrate with external data, manage memory, use tools, and build agents. If you're looking to go beyond simple prompt-response interactions with LLMs, LangChain is a valuable tool to explore.
#
# Let me know if you have any more questions!

# %%
question= "can you tell me the langchain methods"
response = chain.run({"question": question})

print("Question:",question)
print("Answer:", response)
# Out:
# Question: can you tell me the langchain methods
# Answer: Okay, let's talk about LangChain methods. It's a broad topic, so I'll break it down into categories and give you a good overview.
#
# **Understanding LangChain's Structure**
#
# LangChain is a framework for building applications powered by large language models (LLMs). It provides a set of tools and abstractions to make it easier to work with LLMs and integrate them into complex workflows.  Instead of thinking of "methods" in the traditional programming sense, it's more helpful to think of LangChain in terms of its **modules** and the **classes** within those modules.
#
# Here's a breakdown of key areas and the types of "methods" (or more accurately, functionalities) you'll find:
#
# **1. Models (LLMs and Chat Models)**
#
# *   **Purpose:**  Interact with language models.
# *   **Key Classes:**
#     *   `LLM` (Base class for language models)
#     *   `ChatModel` (Base class for chat models)
#     *   Specific implementations like `OpenAI`, `HuggingFaceHub`, `Cohere`, etc.
# *   **Key "Methods" (Functionalities):**
#     *   `generate(prompt)`:  Generates text based on a given prompt (for `LLM`).
#     *   `predict(prompt)`:  Similar to `generate`, but often used for simpler text completion.
#     *   `call(prompt)`:  Another way to invoke the LLM, often used in chains.
#     *   `agenerate(prompt)`: Asynchronous version of `generate`.
#     *   `apredict(prompt)`: Asynchronous version of `predict`.
#     *   `acall(prompt)`: Asynchronous version of `call`.
#     *   `get_num_tokens(text)`:  Calculates the number of tokens in a given text.
#     *   `get_token_ids(text)`: Returns the token IDs for a given text.
#     *   `get_model_name()`: Returns the name of the model.
#     *   `get_llm_parameters()`: Returns the parameters of the model.
#     *   `get_prompt_template()`: Returns the prompt template used by the model.
#     *   `get_stop_sequences()`: Returns the stop sequences used by the model.
#     *   `get_max_tokens()`: Returns the maximum number of tokens that can be generated by the model.
#     *   `get_temperature()`: Returns the temperature used by the model.
#     *   `get_top_p()`: Returns the top_p used by the model.
#     *   `get_frequency_penalty()`: Returns the frequency_penalty used by the model.
#     *   `get_presence_penalty()`: Returns the presence_penalty used by the model.
#     *   `get_n()`: Returns the number of generations to be returned by the model.
#     *   `get_best_of()`: Returns the best of the generations to be returned by the model.
#     *   `get_logprobs()`: Returns the log probabilities of the tokens generated by the model.
#     *   `get_echo()`: Returns the echo of the prompt.
#     *   `get_stream()`: Returns the stream of the tokens generated by the model.
#     *   `get_seed()`: Returns the seed used by the model.
#     *   `get_stop()`: Returns the stop sequences used by the model.
#     *   `get_max_tokens_to_sample()`: Returns the maximum number of tokens to sample from the model.
#     *   `get_logit_bias()`: Returns the logit bias used by the model.
#     *   `get_user()`: Returns the user used by the model.
#     *   `get_model_kwargs()`: Returns the model kwargs used by the model.
#     *   `get_client()`: Returns the client used by the model.
#     *   `get_verbose()`: Returns the verbose used by the model.
#     *   `get_callback_manager()`: Returns the callback manager used by the model.
#     *   `get_tags()`: Returns the tags used by the model.
#     *   `get_metadata()`: Returns the metadata used by the model.
#     *   `get_cache()`: Returns the cache used by the model.
#     *   `get_batch_size()`: Returns the batch size used by the model.
#     *   `get_streaming()`: Returns the streaming used by the model.
#     *   `get_model_type()`: Returns the model type used by the model.
#     *   `get_model_provider()`: Returns the model provider used by the model.
#     *   `get_model_id()`: Returns the model id used by the model.
#     *   `get_model_version()`: Returns the model version used by the model.
#     *   `get_model_endpoint()`: Returns the model endpoint used by the model.
#     *   `get_model_api_key()`: Returns the model api key used by the model.
#     *   `get_model_organization()`: Returns the model organization used by the model.
#     *   `get_model_base_url()`: Returns the model base url used by the model.
#     *   `get_model_timeout()`: Returns the model timeout used by the model.
#     *   `get_model_max_retries()`: Returns the model max retries used by the model.
#     *   `get_model_default_headers()`: Returns the model default headers used by the model.
#     *   `get_model_default_query()`: Returns the model default query used by the model.
#     *   `get_model_default_params()`: Returns the model default params used by the model.
#     *   `get_model_default_data()`: Returns the model default data used by the model.
#     *   `get_model_default_json()`: Returns the model default json used by the model.
#     *   `get_model_default_files()`: Returns the model default files used by the model.
#     *   `get_model_default_stream()`: Returns the model default stream used by the model.
#     *   `get_model_default_verify()`: Returns the model default verify used by the model.
#     *   `get_model_default_proxies()`: Returns the model default proxies used by the model.
#     *   `get_model_default_cert()`: Returns the model default cert used by the model.
#     *   `get_model_default_timeout()`: Returns the model default timeout used by the model.
#     *   `get_model_default_max_retries()`: Returns the model default max retries used by the model.
#     *   `get_model_default_retry_delay()`: Returns the model default retry delay used by the model.
#     *   `get_model_default_retry_jitter()`: Returns the model default retry jitter used by the model.
#     *   `get_model_default_retry_exponential_backoff()`: Returns the model default retry exponential backoff used by the model.
#     *   `get_model_default_retry_status_codes()`: Returns the model default retry status codes used by the model.
#     *   `get_model_default_retry_method_whitelist()`: Returns the model default retry method whitelist used by the model.
#     *   `get_model_default_retry_on_connection_error()`: Returns the model default retry on connection error used by the model.
#     *   `get_model_default_retry_on_rate_limit()`: Returns the model default retry on rate limit used by the model.
#     *   `get_model_default_retry_on_server_error()`: Returns the model default retry on server error used by the model.
#     *   `get_model_default_retry_on_timeout()`: Returns the model default retry on timeout used by the model.
#     *   `get_model_default_retry_on_api_error()`: Returns the model default retry on api error used by the model.
#     *   `get_model_default_retry_on_api_limit()`: Returns the model default retry on api limit used by the model.
#     *   `get_model_default_retry_on_api_unavailable()`: Returns the model default retry on api unavailable used by the model.
#     *   `get_model_default_retry_on_api_internal_error()`: Returns the model default retry on api internal error used by the model.
#     *   `get_model_default_retry_on_api_bad_request()`: Returns the model default retry on api bad request used by the model.
#     *   `get_model_default_retry_on_api_unauthorized()`: Returns the model default retry on api unauthorized used by the model.
#     *   `get_model_default_retry_on_api_forbidden()`: Returns the model default retry on api forbidden used by the model.
#     *   `get_model_default_retry_on_api_not_found()`: Returns the model default retry on api not found used by the model.
#     *   `get_model_default_retry_on_api_method_not_allowed()`: Returns the model default retry on api method not allowed used by the model.
#     *   `get_model_default_retry_on_api_not_acceptable()`: Returns the model default retry on api not acceptable used by the model.
#     *   `get_model_default_retry_on_api_proxy_authentication_required()`: Returns the model default retry on api proxy authentication required used by the model.
#     *   `get_model_default_retry_on_api_request_timeout()`: Returns the model default retry on api request timeout used by the model.
#     *   `get_model_default_retry_on_api_conflict()`: Returns the model default retry on api conflict used by the model.
#     *   `get_model_default_retry_on_api_gone()`: Returns the model default retry on api gone used by the model.
#     *   `get_model_default_retry_on_api_length_required()`: Returns the model default retry on api length required used by the model.
#     *   `get_model_default_retry_on_api_precondition_failed()`: Returns the model default retry on api precondition failed used by the model.
#     *   `get_model_default_retry_on_api_payload_too_large()`: Returns the model default retry on api payload too large used by the model.
#     *   `get_model_default_retry_on_api_uri_too_long()`: Returns the model default retry on api uri too long used by the model.
#     *   `get_model_default_retry_on_api_unsupported_media_type()`: Returns the model default retry on api unsupported media type used by the model.
#     *   `get_model_default_retry_on_api_range_not_satisfiable()`: Returns the model default retry on api range not satisfiable used by the model.
#     *   `get_model_default_retry_on_api_expectation_failed()`: Returns the model default retry on api expectation failed used by the model.
#     *   `get_model_default_retry_on_api_im_a_teapot()`: Returns the model default retry on api im a teapot used by the model.
#     *   `get_model_default_retry_on_api_misdirected_request()`: Returns the model default retry on api misdirected request used by the model.
#     *   `get_model_default_retry_on_api_unprocessable_entity()`: Returns the model default retry on api unprocessable entity used by the model.
#     *   `get_model_default_retry_on_api_locked()`: Returns the model default retry on api locked used by the model.
#     *   `get_model_default_retry_on_api_failed_dependency()`: Returns the model default retry on api failed dependency used by the model.
#     *   `get_model_default_retry_on_api_too_early()`: Returns the model default retry on api too early used by the model.
#     *   `get_model_default_retry_on_api_upgrade_required()`: Returns the model default retry on api upgrade required used by the model.
#     *   `get_model_default_retry_on_api_precondition_required()`: Returns the model default retry on api precondition required used by the model.
#     *   `get_model_default_retry_on_api_too_many_requests()`: Returns the model default retry on api too many requests used by the model.
#     *   `get_model_default_retry_on_api_request_header_fields_too_large()`: Returns the model default retry on api request header fields too large used by the model.
#     *   `get_model_default_retry_on_api_unavailable_for_legal_reasons()`: Returns the model default retry on api unavailable for legal reasons used by the model.
#     *   `get_model_default_retry_on_api_client_closed_request()`: Returns the model default retry on api client closed request used by the model.
#     *   `get_model_default_retry_on_api_internal_server_error()`: Returns the model default retry on api internal server error used by the model.
#     *   `get_model_default_retry_on_api_not_implemented()`: Returns the model default retry on api not implemented used by the model.
#     *   `get_model_default_retry_on_api_bad_gateway()`: Returns the model default retry on api bad gateway used by the model.
#     *   `get_model_default_retry_on_api_service_unavailable()`: Returns the model default retry on api service unavailable used by the model.
#     *   `get_model_default_retry_on_api_gateway_timeout()`: Returns the model default retry on api gateway timeout used by the model.
#     *   `get_model_default_retry_on_api_http_version_not_supported()`: Returns the model default retry on api http version not supported used by the model.
#     *   `get_model_default_retry_on_api_variant_also_negotiates()`: Returns the model default retry on api variant also negotiates used by the model.
#     *   `get_model_default_retry_on_api_insufficient_storage()`: Returns the model default retry on api insufficient storage used by the model.
#     *   `get_model_default_retry_on_api_loop_detected()`: Returns the model default retry on api loop detected used by the model.
#     *   `get_model_default_retry_on_api_not_extended()`: Returns the model default retry on api not extended used by the model.
#     *   `get_model_default_retry_on_api_network_authentication_required()`: Returns the model default retry on api network authentication required used by the model.
#     *   `get_model_default_retry_on_api_network_connect_timeout_error()`: Returns the model default retry on api network connect timeout error used by the model.
#     *   `get_model_default_retry_on_api_network_read_timeout_error()`: Returns the model default retry on api network read timeout error used by the model.
#     *   `get_model_default_retry_on_api_network_write_timeout_error()`: Returns the model default retry on api network write timeout error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_error()`: Returns the model default retry on api network connection error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_reset_error()`: Returns the model default retry on api network connection reset error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_refused_error()`: Returns the model default retry on api network connection refused error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_aborted_error()`: Returns the model default retry on api network connection aborted error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_closed_error()`: Returns the model default retry on api network connection closed error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_timeout_error()`: Returns the model default retry on api network connection timeout error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_refused_error()`: Returns the model default retry on api network connection refused error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_aborted_error()`: Returns the model default retry on api network connection aborted error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_closed_error()`: Returns the model default retry on api network connection closed error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_timeout_error()`: Returns the model default retry on api network connection timeout error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_reset_error()`: Returns the model default retry on api network connection reset error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_refused_error()`: Returns the model default retry on api network connection refused error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_aborted_error()`: Returns the model default retry on api network connection aborted error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_closed_error()`: Returns the model default retry on api network connection closed error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_timeout_error()`: Returns the model default retry on api network connection timeout error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_reset_error()`: Returns the model default retry on api network connection reset error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_refused_error()`: Returns the model default retry on api network connection refused error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_aborted_error()`: Returns the model default retry on api network connection aborted error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_closed_error()`: Returns the model default retry on api network connection closed error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_timeout_error()`: Returns the model default retry on api network connection timeout error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_reset_error()`: Returns the model default retry on api network connection reset error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_refused_error()`: Returns the model default retry on api network connection refused error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_aborted_error()`: Returns the model default retry on api network connection aborted error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_closed_error()`: Returns the model default retry on api network connection closed error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_timeout_error()`: Returns the model default retry on api network connection timeout error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_reset_error()`: Returns the model default retry on api network connection reset error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_refused_error()`: Returns the model default retry on api network connection refused error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_aborted_error()`: Returns the model default retry on api network connection aborted error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_closed_error()`: Returns the model default retry on api network connection closed error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_timeout_error()`: Returns the model default retry on api network connection timeout error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_reset_error()`: Returns the model default retry on api network connection reset error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_refused_error()`: Returns the model default retry on api network connection refused error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_aborted_error()`: Returns the model default retry on api network connection aborted error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_closed_error()`: Returns the model default retry on api network connection closed error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_timeout_error()`: Returns the model default retry on api network connection timeout error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_reset_error()`: Returns the model default retry on api network connection reset error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_refused_error()`: Returns the model default retry on api network connection refused error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_aborted_error()`: Returns the model default retry on api network connection aborted error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_closed_error()`: Returns the model default retry on api network connection closed error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_timeout_error()`: Returns the model default retry on api network connection timeout error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_reset_error()`: Returns the model default retry on api network connection reset error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_refused_error()`: Returns the model default retry on api network connection refused error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_aborted_error()`: Returns the model default retry on api network connection aborted error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_closed_error()`: Returns the model default retry on api network connection closed error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_timeout_error()`: Returns the model default retry on api network connection timeout error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_reset_error()`: Returns the model default retry on api network connection reset error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_refused_error()`: Returns the model default retry on api network connection refused error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_aborted_error()`: Returns the model default retry on api network connection aborted error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_closed_error()`: Returns the model default retry on api network connection closed error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_timeout_error()`: Returns the model default retry on api network connection timeout error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_reset_error()`: Returns the model default retry on api network connection reset error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_refused_error()`: Returns the model default retry on api network connection refused error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_aborted_error()`: Returns the model default retry on api network connection aborted error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_closed_error()`: Returns the model default retry on api network connection closed error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_timeout_error()`: Returns the model default retry on api network connection timeout error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_reset_error()`: Returns the model default retry on api network connection reset error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_refused_error()`: Returns the model default retry on api network connection refused error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_aborted_error()`: Returns the model default retry on api network connection aborted error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_closed_error()`: Returns the model default retry on api network connection closed error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_timeout_error()`: Returns the model default retry on api network connection timeout error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_reset_error()`: Returns the model default retry on api network connection reset error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_refused_error()`: Returns the model default retry on api network connection refused error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_aborted_error()`: Returns the model default retry on api network connection aborted error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_closed_error()`: Returns the model default retry on api network connection closed error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_timeout_error()`: Returns the model default retry on api network connection timeout error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_reset_error()`: Returns the model default retry on api network connection reset error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_refused_error()`: Returns the model default retry on api network connection refused error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_aborted_error()`: Returns the model default retry on api network connection aborted error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_closed_error()`: Returns the model default retry on api network connection closed error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_timeout_error()`: Returns the model default retry on api network connection timeout error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_reset_error()`: Returns the model default retry on api network connection reset error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_refused_error()`: Returns the model default retry on api network connection refused error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_aborted_error()`: Returns the model default retry on api network connection aborted error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_closed_error()`: Returns the model default retry on api network connection closed error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_timeout_error()`: Returns the model default retry on api network connection timeout error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_reset_error()`: Returns the model default retry on api network connection reset error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_refused_error()`: Returns the model default retry on api network connection refused error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_aborted_error()`: Returns the model default retry on api network connection aborted error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_closed_error()`: Returns the model default retry on api network connection closed error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_timeout_error()`: Returns the model default retry on api network connection timeout error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_reset_error()`: Returns the model default retry on api network connection reset error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_refused_error()`: Returns the model default retry on api network connection refused error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_aborted_error()`: Returns the model default retry on api network connection aborted error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_closed_error()`: Returns the model default retry on api network connection closed error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_timeout_error()`: Returns the model default retry on api network connection timeout error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_reset_error()`: Returns the model default retry on api network connection reset error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_refused_error()`: Returns the model default retry on api network connection refused error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_aborted_error()`: Returns the model default retry on api network connection aborted error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_closed_error()`: Returns the model default retry on api network connection closed error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_timeout_error()`: Returns the model default retry on api network connection timeout error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_reset_error()`: Returns the model default retry on api network connection reset error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_refused_error()`: Returns the model default retry on api network connection refused error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_aborted_error()`: Returns the model default retry on api network connection aborted error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_closed_error()`: Returns the model default retry on api network connection closed error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_timeout_error()`: Returns the model default retry on api network connection timeout error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_reset_error()`: Returns the model default retry on api network connection reset error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_refused_error()`: Returns the model default retry on api network connection refused error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_aborted_error()`: Returns the model default retry on api network connection aborted error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_closed_error()`: Returns the model default retry on api network connection closed error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_timeout_error()`: Returns the model default retry on api network connection timeout error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_reset_error()`: Returns the model default retry on api network connection reset error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_refused_error()`: Returns the model default retry on api network connection refused error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_aborted_error()`: Returns the model default retry on api network connection aborted error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_closed_error()`: Returns the model default retry on api network connection closed error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_timeout_error()`: Returns the model default retry on api network connection timeout error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_reset_error()`: Returns the model default retry on api network connection reset error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_refused_error()`: Returns the model default retry on api network connection refused error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_aborted_error()`: Returns the model default retry on api network connection aborted error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_closed_error()`: Returns the model default retry on api network connection closed error used by the model.
#     *   `get_model_default_retry_on_api_network_connection_timeout_error()`
